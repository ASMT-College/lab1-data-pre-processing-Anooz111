# %% [markdown]
# ## Employee Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('employee_data.csv')
data.head(50)
# Out:
#     ID     Name   Age       Department   Salary
# 0    1     John  28.0               HR  50000.0
# 1    2     Jane  35.0          Finance  60000.0
# 2    3    Emily   NaN               HR  55000.0
# 3    4  Michael  40.0  Human Resources      NaN
# 4    5    Sarah  29.0               IT  52000.0
# 5    6    David  50.0          Finance  75000.0
# 6    7    Laura  38.0             H.R.  68000.0
# 7    8   Robert  32.0               HR  57000.0
# 8    9    Linda  45.0               IT  62000.0
# 9   10    James  30.0               HR  51000.0
# 10  11    James  30.0               HR  51000.0

# %%
mean_age = data['Age'].mean()
mean_age_ceil = np.ceil(mean_age)

data['Age'].fillna(mean_age_ceil, inplace=True)
# Out:
# C:\Users\anuj\AppData\Local\Temp\ipykernel_26560\596232980.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(mean_age_ceil, inplace=True)

# %%
mean_salary = data['Salary'].mean()
mean_salary_ceil = np.ceil(mean_salary)
data['Salary'].fillna(mean_salary_ceil, inplace=True)
# Out:
# C:\Users\anuj\AppData\Local\Temp\ipykernel_26560\3119775536.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Salary'].fillna(mean_salary_ceil, inplace=True)

# %%
unique_departments = data['Department'].unique()
unique_departments
# Out:
# array(['HR', 'Finance', 'Human Resources', 'IT', 'H.R.'], dtype=object)

# %%
data['Department'] = data['Department'].replace({
    'H.R.':'HR',
    'HR': 'HR',
    'Human Resources': 'HR',

})

# %%
data.drop_duplicates(subset='ID', keep='first', inplace=True)
data
# Out:
#     ID     Name   Age Department   Salary
# 0    1     John  28.0         HR  50000.0
# 1    2     Jane  35.0    Finance  60000.0
# 2    3    Emily  36.0         HR  55000.0
# 3    4  Michael  40.0         HR  58100.0
# 4    5    Sarah  29.0         IT  52000.0
# 5    6    David  50.0    Finance  75000.0
# 6    7    Laura  38.0         HR  68000.0
# 7    8   Robert  32.0         HR  57000.0
# 8    9    Linda  45.0         IT  62000.0
# 9   10    James  30.0         HR  51000.0
# 10  11    James  30.0         HR  51000.0

# %% [markdown]
# ## Student data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
std_df = pd.read_csv('student_scores.csv')
std_df.head()
# Out:
#    StudentID  Math  Science  English
# 0          1    78       65       80
# 1          2    88       75       85
# 2          3    60       50       55
# 3          4    90       78       92
# 4          5    55       48       58

# %%
scaler = MinMaxScaler()
std_df[['Math', 'Science', 'English']] = scaler.fit_transform(std_df[['Math', 'Science', 'English']])
std_df.head()
# Out:
#    StudentID      Math  Science   English
# 0          1  0.657143  0.53125  0.675676
# 1          2  0.942857  0.84375  0.810811
# 2          3  0.142857  0.06250  0.000000
# 3          4  1.000000  0.93750  1.000000
# 4          5  0.000000  0.00000  0.081081

# %% [markdown]
# ## Customer Data

# %%
cus_df = pd.read_csv('customer_ages.csv')
cus_df.head()
# Out:
#    CustomerID  Age
# 0           1   25
# 1           2   42
# 2           3   36
# 3           4   53
# 4           5   28

# %%
bins = [18, 30, 50, 100]
labels = ['Young', 'Middle-aged', 'Senior']
cus_df['AgeGroup'] = pd.cut(cus_df['Age'], bins=bins, labels=labels, right=False)

cus_df.head()
# Out:
#    CustomerID  Age     AgeGroup
# 0           1   25        Young
# 1           2   42  Middle-aged
# 2           3   36  Middle-aged
# 3           4   53       Senior
# 4           5   28        Young

# %% [markdown]
# ## Sales data

# %%
sales_df = pd.read_csv('sales_data.csv')
sales_df.head()
# Out:
#       Month  Sales
# 0   January  15000
# 1  February  18000
# 2     March  12000
# 3     April  30000
# 4       May  22000

# %%
bins = [0, 5000, 20000, float('inf')]
labels = ['Low', 'Medium', 'High']
sales_df['SalesCategory'] = pd.cut(sales_df['Sales'], bins=bins, labels=labels)
sales_df.head()
# Out:
#       Month  Sales SalesCategory
# 0   January  15000        Medium
# 1  February  18000        Medium
# 2     March  12000        Medium
# 3     April  30000          High
# 4       May  22000          High

# %%
sales_category_distribution = sales_df['SalesCategory'].value_counts()
print("\nSales Category Distribution:\n", sales_category_distribution)
# Out:
# Sales Category Distribution:
#  SalesCategory
# Medium    7
# High      4
# Low       1
# Name: count, dtype: int64

# %% [markdown]
# ## Medical Data

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
med_df = pd.read_csv('medical_data.csv')
med_df.head()
# Out:
#    PatientID  Age  BloodPressure  Cholesterol  Glucose  HeartRate  Disease
# 0          1   45            130          180       95         70        1
# 1          2   50            140          200      105         75        1
# 2          3   60            150          240      120         80        1
# 3          4   40            120          170       90         65        0
# 4          5   35            110          160       85         60        0

# %%
X = med_df.drop(columns=['Disease'])
y = med_df['Disease']

# %%
selector = SelectKBest(score_func=chi2, k=3)
selector.fit(X, y)
# Out:
# SelectKBest(k=3, score_func=<function chi2 at 0x000001C7D8479940>)

# %%
top_features = X.columns[selector.get_support()]
print("\nTop 3 Features for Predicting Disease:\n", top_features)
# Out:
# Top 3 Features for Predicting Disease:
#  Index(['Age', 'Cholesterol', 'Glucose'], dtype='object')
